# %% [markdown]
# # Plot
# plt.plot(x,y) and sns.regplot(x,y,scatter_kws,line_kws)
# ax = plt.axes()   and  ax.set_xticks()  or ax.set_yticks()  or  ax.set(xlabel,ylabel)  or  ax.set_title()
# # Attribute
# linestyle(ls),color(c),marker(m),size(s),alpha,xlabel(),ylabel(),legend(loc),annotate()
# #
# # Box Plot
# plt/df.boxplot(x)  and sns.boxplot(x,y)[import seaborn as sns]
# # Attributes
# widths,notch
# #
# # Scatter Plot
# plt.scatter(x,y)
# # Attribute
# marker,color,s(size),alpha
# #
# # Area Plot
# plt.fill_between(x,y,z)  and  use where for 2 plot
# # Attribute
# color(c),alpha,interpolate
# #
# # Stacked Area Chart
# plt.stackplot(x,y,z)
# fig,ax = plt.subplots()  and  ax.set_xticks()
# # Attributes
# labels,colors(color for one),loc(plt.legend()),suptitle()
# #
# # Waffle charts
# fig = plt.figure(FigureClass=Waffle)
# # Attribute
# rows,values,labels,legend,characters,title()
# #
# # Word Clouds
# alice_novel=open().read()
# alice_wc=WordCloud(background_color='white,max_words=2000,stopwords=stopwords)
# alice_wc.generate(alice_novel)
# plt.imshow(alice_wc)  plt.axis('off')
# #
# # Heatmaps
# data = np.random.randint(low=1,high=100,size=(10,10))
# sns.heatmap(data=data)
# # Attribute
# vmin,vmax,cmap(tab20,coolwarm),annot=True,linewidths(lw),linecolor,cbar=False,xticklabels,yticklabels
# #
# # Graph
# undirected  :-  g=nx.Graph() g.add_node() g.add_egde() g.add_nodes_from() g.add_edges_from() nx.draw(g)
# directed  :-  g=nx.DiGraph() g.add_node() g.add_egde() g.add_nodes_from() g.add_edges_from() nx.draw(g)
# # Attribute
# with_labels=True,node_size,node_color,edge_color,width
# #
# # Geospatial Data
# m = folium.Map(),
# folium.LayerControl().add_to(m),
# folium.GeoJson().add_to(m),
# folium.Circle().add_to(m),
# folium.map.FeatureGroup()[for read from csv file],
# folium.Choropleth().add_to(m)
# # Attribute
# location,zoom_start||data(json file),name||radius,color,weight,fill,fil_color,fill_opacity,max_width,tooltip,popup=folium.Popup(link)||geo_data,name,data(read csv),columns,key_on,fill_color,line_opacity,fill_opacity,legend_name

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pywaffle import Waffle
from wordcloud import WordCloud,STOPWORDS
import networkx as nx
import folium

# %%
data = {'year':[2021,2022,2023,2024,2025],'sales':[100,120,150,170,200],'expenses':[70,180,90,250,110]}
fig,ax = plt.subplots()
df = pd.DataFrame(data)
# print(df)
# plt.stackplot(df['year'],df['sales'],df['expenses'],labels=['sale','expense'],colors=['purple','pink'])
# plt.legend(loc='upper left')
# plt.show()

# plt.fill_between(df['year'],df['sales'],df['expenses'])
# plt.plot(df['year'],df['sales'],color='yellow')
# plt.plot(df['year'],df['expenses'],color='orange')
# plt.show()

# ax.fill_between(df['year'],df['sales'],df['expenses'])
# ax.plot(df['year'],df['sales'],color='yellow')
# ax.plot(df['year'],df['expenses'],color='orange')
# ax.set_xticks([2021,2022,2023,2024,2025])
# plt.show()

ax.fill_between(df['year'],df['sales'],df['expenses'],where=df.sales>df.expenses,color='green',interpolate=True)
ax.fill_between(df['year'],df['sales'],df['expenses'],where=df.sales<df.expenses,color='red',interpolate=True)
ax.set_xticks([2021,2022,2023,2024,2025])
plt.show()

# %%
d = pd.read_csv('auto-mpg.csv')
df = pd.DataFrame(d)
# fig,ax = plt.subplots()
df.boxplot(column=['mpg','weight'],widths=0.75,notch=True)
fig.suptitle('Tithi23')
plt.show()

df.boxplot(column=['mpg','weight'],widths=0.75,notch=True,by=['cylinders'])
plt.show()

# %%
sns.boxplot(x=df.cylinders,y=df.mpg,data=df)
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='mpg'>

# %%
d = pd.read_csv('auto-mpg.csv')
df = pd.DataFrame(d)
# plt.scatter(df['mpg'],df['acceleration'],marker='v',s=100,color='red')
# plt.scatter(df['mpg'],df['displacement'],marker='v',s=100,color='green')
# plt.show()
# plt.scatter(df['mpg'],df['displacement'],marker='v',s=100,color='green')
# plt.show()

# plt.plot(df['mpg'],df['acceleration'])
# plt.show()
sns.regplot(x=df['mpg'],y=df['acceleration'],scatter_kws={'color':'pink','marker':'d','s':30,'alpha':0.5},
            line_kws={'color':'purple','ls':':','lw':2})
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='acceleration'>

# %%
data = np.random.randint(low=1,high=100,size=(10,10))
# sns.heatmap(data=data)
# sns.heatmap(data=df.corr())
sns.heatmap(data=data,annot=True,vmax=60,vmin=20,cmap='tab20',lw=2,linecolor='red',cbar=False)  #tab20/coolwarm
# Out:
# <AxesSubplot:>

# %%
data = {'c':['A','B','C','D'],'v':[20,35,15,30]}
df = pd.DataFrame(data)
fig = plt.figure(FigureClass=Waffle,rows=10,values=df['v'],labels=list(df['c']),legend={'loc':'upper left'},characters='😉')
plt.title('B1 is best')
plt.show()
# Out:
# <Waffle size 432x288 with 1 Axes>

# %%
stopwords = set(STOPWORDS)
# print(stopwords)

import requests
url = 'https://www.gutenberg.org/files/11/11-0.txt'
response = requests.get(url)
text = response.text
# print(text)

# alice_wc = WordCloud(background_color='white',max_words=2000,stopwords=stopwords)
# alice_wc.generate(text)
# plt.imshow(alice_wc)
# plt.axis('off')
# plt.show()

# %%
g = nx.Graph()
g.add_node(1)
g.add_node(2)
g.add_node(3)
g.add_edge(1,2)
g.add_edge(2,3)
g.add_edge(3,1)
nx.draw(g,with_labels=True)
plt.show()

# %%
g = nx.DiGraph()
g.add_node(1)
g.add_node(2)
g.add_node(3)
g.add_edge(1,2)
g.add_edge(2,3)
g.add_edge(3,1)
nx.draw(g,with_labels=True)
plt.show()

# %%
g = nx.DiGraph()
g.add_node(1)
g.add_nodes_from([2,3])
g.add_nodes_from(range(4,7))
g.add_edge(1,2)
g.add_edge(1,1)
g.add_edges_from([(2,3),(3,6),(4,6),(5,6)])
nx.draw(g,with_labels=True,node_size=850,node_color='red',width=5,edge_color='green')
plt.show()

# %%
g=nx.DiGraph()
l=[[1,0,0,1,0,1,1],[0,1,1,1,1,1,0],[1,1,1,0,1,0,1]]
g.add_nodes_from([0,1,2])
for i in range(0,3):
    for j in range(0,3):
        if l[i][j] == 1:
            g.add_edge(i,j)
nx.draw(g,with_labels=True,node_size=850,node_color='red',width=5,edge_color='green')
plt.show()

# %%
m = folium.Map(location = [23.43,72.58],zoom_start = 8)
m

folium.LayerControl().add_to(m)
m
m.save('output.html')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
m = folium.Map(location = [23.43,72.58],zoom_start = 8)
layer = folium.GeoJson(data=('us-states.json'),name = 'us')
layer.add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
m = folium.Map(location = [23.43,72.58],zoom_start = 8)
folium.Circle(location=[23.43,72.58],radius=5000,color='green',weight=6,fill_color='blue',fill_opacity=0.5).add_to(m)
folium.Circle(location=[29.43,80.58],radius=15000,color='green',weight=6,fill_color='blue',fill_opacity=0.5).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
m = folium.Map(location = [23.43,72.58],zoom_start = 8)
folium.Circle(location=[23.43,72.58],radius=5000,color='green',weight=6,fill_color='blue',fill_opacity=0.5,fill=True,
              tooltip="this is a tooltip",popup=folium.Popup("<a href='http://localhost:8888/tree'>link</a>",max_width=500)).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
d = pd.read_csv('Police_Department_Incidents_-_Previous_Year__2016_.csv')
df = pd.DataFrame(d)
df = df.iloc[0:100,:]
m = folium.Map(location=[37.7749,-122.4194],zomm_start=13)
incident = folium.map.FeatureGroup()
m

d = pd.read_csv('Police_Department_Incidents_-_Previous_Year__2016_.csv')
df = pd.DataFrame(d)
df = df.iloc[0:100,:]
m = folium.Map(location=[37.7749,-122.4194],zomm_start=13)
incident = folium.map.FeatureGroup()
for lat,lon,category in zip(df.Y,df.X,df.Category):
    popup_text = f'Category:{category}'
    marker = folium.CircleMarker(location=[lat,lon],radius=7,color='yellow',fill=True,fill_color='blue',
                                 popup=folium.Popup(popup_text))
    marker.add_to(incident)
incident.add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
m = folium.Map(location=[48,-102],zoom_start=3)
folium.Choropleth(geo_data='us-states.json',name='choropleth',data=pd.read_csv('US_Unemployment_Oct2012.csv'),
                  columns=['State','Unemployment'],key_on='feature.id',fill_color='YlGnBu',line_opacity=0.2,
                  fill_opacity=0.7,legend_name='unemployment_scale').add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
